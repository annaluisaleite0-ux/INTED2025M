# %% [markdown]
# <a href="https://colab.research.google.com/github/annaluisaleite0-ux/INTED2025M/blob/main/ALP_M33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritmo e Lógica de Programação

# %% [markdown]
# ##Variáveis

# %%
a = 50
b = 15
print(a+b)
# Out:
# 65

# %% [markdown]
# ##Tipos de Dados
#
# int - inteiros - para números inteiros
#
# float - flutuantes - para números com vírgula
#
# str - string - para palavras e textos
#
# bool - booleano -  para binários - True ou False

# %%
x = int(input("Digite um número: "))
y = float(input("Digite um número com vírgula: "))
z = str(input("Digite uma palavra: "))
w = bool(input("Digite um binário: "))
# Out:
# Digite um número: 16
# Digite um número com vírgula: 1.5
# Digite uma palavra: palavra
# Digite um binário: True

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 16
# 1.5
# palavra
# True

# %%
print("Este é um número inteiro: ", x, "Outro texto")
# Out:
# Este é um número inteiro:  16 Outro texto

# %% [markdown]
# 1 - Crie um algoritmo que receba em uma variável um nome, e em outra uma idade. (nome,idade) depois mostre na tela a seguinte frase:
#
# Eu sou **nome** e tenho **idade** anos!

# %%
nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
print("Eu sou a", nome, "e tenho", idade, "anos!")
# Out:
# Digite seu nome: Anna Luisa
# Digite sua idade: 16
# Eu sou a Anna Luisa e tenho 16 anos!

# %% [markdown]
# ##Operadores
#
# Adição +
#
# Subtração -
#
# Multiplicação *
#
# Divisão /
#
# Resto da Divisão %
#
# Exponenciação **

# %% [markdown]
# 2 -  Crie um algoritmo que leia 2 números e imprima na tela o resultado das operações acima.
